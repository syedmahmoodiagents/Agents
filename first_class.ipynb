# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmahmoodiagents/Agents/blob/main/first_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
0.2 + 0.1
# Out:
# 0.30000000000000004

# %%
"aa" + "m"
# Out:
# 'aam'

# %%
"a" + "3"
# Out:
# 'a3'

# %%
"_" * 30
# Out:
# '______________________________'
