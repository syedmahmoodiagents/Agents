# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmahmoodiagents/Agents/blob/main/ReAct_with_WikiTools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-core langchain-community langgraph langchain-openai openai wikipedia --q

# %%
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_community.tools import WikipediaQueryRun

# %%
api_wrapper = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=100)

# %%
wiki_tool = WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
wiki_tool.run({"query": "AI Agents"})
# Out:
# 'Page: Agentic AI\nSummary: In artificial intelligence, agentic AI focuses on autonomous systems that '

# %%
import os, getpass

# %%
os.environ['OPENAI_API_KEY'] = getpass.getpass()
# Out:
# ··········

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
tools = [wiki_tool]

# %%
llm_with_tools = llm.bind_tools([wiki_tool])

# %%
result = llm_with_tools.invoke("hello world")

# %%
result.content
# Out:
# 'Hello! How can I assist you today?'

# %%
res = llm_with_tools.invoke("who invented internet ?")

# %%
res.content
# Out:
# ''

# %%
from langgraph.prebuilt import create_react_agent
from langchain_core.messages import HumanMessage

# %%
agent_executor = create_react_agent(llm, tools)
# Out:
# /tmp/ipython-input-494191090.py:1: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent_executor = create_react_agent(llm, tools)

# %%
response = agent_executor.invoke({"messages": [HumanMessage(content="Hi!")]})

# %%
response
# Out:
# {'messages': [HumanMessage(content='Hi!', additional_kwargs={}, response_metadata={}, id='e5400b6d-1757-42e7-85d7-c9187253ee77'),
#   AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 83, 'total_tokens': 93, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CayYZ8K8TFrKfjpFDcKpTYRqP8LRE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--2befd8d4-6529-45fb-ba1a-3e05c4c1aa68-0', usage_metadata={'input_tokens': 83, 'output_tokens': 10, 'total_tokens': 93, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
response['messages'][-1].content
# Out:
# 'Hello! How can I assist you today?'

# %%
res = agent_executor.invoke({"messages": [HumanMessage(content="What is agentic AI ?")]})

# %%
res
# Out:
# {'messages': [HumanMessage(content='What is agentic AI ?', additional_kwargs={}, response_metadata={}, id='65b38e91-8615-42d6-9bca-1dfa49641dd0'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_GYPyYJ3JGI5Q39cKOksq9iwb', 'function': {'arguments': '{"query":"Agentic AI"}', 'name': 'wikipedia'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 87, 'total_tokens': 102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-Caz7e9kLRmxmpQ3ELoLhJlGtumXQW', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--8e926b70-03c1-4b81-8665-d27534de86b2-0', tool_calls=[{'name': 'wikipedia', 'args': {'query': 'Agentic AI'}, 'id': 'call_GYPyYJ3JGI5Q39cKOksq9iwb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 15, 'total_tokens': 102, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='Page: Agentic AI\nSummary: In artificial intelligence, agentic AI focuses on autonomous systems that ', name='wikipedia', id='54850cad-7711-4108-bf19-cc81201e4f9c', tool_call_id='call_GYPyYJ3JGI5Q39cKOksq9iwb'),
#   AIMessage(content='Agentic AI refers to a branch of artificial intelligence that emphasizes autonomous systems capable of making decisions and acting independently. This type of AI is designed to perform tasks or fulfill objectives without direct human intervention, essentially acting as an "agent" in various environments. The concept encompasses various technologies and applications where AI can function autonomously, adapting to its surroundings and learning from experiences.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 131, 'total_tokens': 205, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-Caz7gajpwF95zo6imdtzpE5jHmlWn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--85a2f315-b3f2-4e65-99b6-18b2460e4b41-0', usage_metadata={'input_tokens': 131, 'output_tokens': 74, 'total_tokens': 205, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
res['messages']
# Out:
# [HumanMessage(content='What is agentic AI ?', additional_kwargs={}, response_metadata={}, id='65b38e91-8615-42d6-9bca-1dfa49641dd0'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_GYPyYJ3JGI5Q39cKOksq9iwb', 'function': {'arguments': '{"query":"Agentic AI"}', 'name': 'wikipedia'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 87, 'total_tokens': 102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-Caz7e9kLRmxmpQ3ELoLhJlGtumXQW', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--8e926b70-03c1-4b81-8665-d27534de86b2-0', tool_calls=[{'name': 'wikipedia', 'args': {'query': 'Agentic AI'}, 'id': 'call_GYPyYJ3JGI5Q39cKOksq9iwb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 87, 'output_tokens': 15, 'total_tokens': 102, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='Page: Agentic AI\nSummary: In artificial intelligence, agentic AI focuses on autonomous systems that ', name='wikipedia', id='54850cad-7711-4108-bf19-cc81201e4f9c', tool_call_id='call_GYPyYJ3JGI5Q39cKOksq9iwb'),
#  AIMessage(content='Agentic AI refers to a branch of artificial intelligence that emphasizes autonomous systems capable of making decisions and acting independently. This type of AI is designed to perform tasks or fulfill objectives without direct human intervention, essentially acting as an "agent" in various environments. The concept encompasses various technologies and applications where AI can function autonomously, adapting to its surroundings and learning from experiences.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 131, 'total_tokens': 205, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-Caz7gajpwF95zo6imdtzpE5jHmlWn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--85a2f315-b3f2-4e65-99b6-18b2460e4b41-0', usage_metadata={'input_tokens': 131, 'output_tokens': 74, 'total_tokens': 205, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
res['messages'][-1].content
# Out:
# 'Agentic AI refers to a branch of artificial intelligence that emphasizes autonomous systems capable of making decisions and acting independently. This type of AI is designed to perform tasks or fulfill objectives without direct human intervention, essentially acting as an "agent" in various environments. The concept encompasses various technologies and applications where AI can function autonomously, adapting to its surroundings and learning from experiences.'
